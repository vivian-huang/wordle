# %%
import random
import pygame
from pygame.locals import *
import sys
import enum
import time

pygame.init()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# (5, 0)

# %%
#https://colorcodes.io/
white = (255,255,255)
yellow = (202,181,87)
green = (106,172,100)
black = (0,0,0)
gray = (121,125,127)
red = (205,0,26)

# %%
font = pygame.font.SysFont("Helvetica neue", 35)
font.set_bold(True)
small_font = pygame.font.SysFont("Helvetica neue", 25)

# %%
manual_statement = small_font.render("Press 'M' for Manual Wordle", True, black)
automatic_statement = small_font.render("Press 'A' for AI Wordle", True, black)

normal_statement = small_font.render("Press 'N' for Normal Mode", True, black)
hard_statement = small_font.render("Press 'H' for Hard Mode", True, black)


win_statement = font.render("Congrats, You Win!", True, green)
lose_statement = font.render("You Lost :(", True, red)
replay_statement = small_font.render("Press RETURN to Play Again!", True, green)

# %%
class GameDifficulty(enum.Enum):
    normal = 0
    hard = 1

class PlayerMode(enum.Enum):
    manual = 0
    automatic = 1

# %%
class Wordle:
    def __init__(self, difficulty, player_mode, wordle_solutions):
        self.difficulty = difficulty
        self.player_mode = player_mode
        self.try_count = 0
        self.game_count = 0
        self.solution_set = wordle_solutions
        self.solution = wordle_solutions[random.randint(0, len(wordle_solutions)-1)].upper()

    def generate_new_solution(self):
        self.solution = self.solution_set[random.randint(0, len(self.solution_set)-1)].upper()
        
    def check_guess(self, turns, answer, guess, window):
        self.try_count += 1
        print("Your current ratio is ", self.get_stats())


        word_space = ["","","","","",""]
        spacing = 0
        word_color = [white, white, white, white, white]
        word_length = 5
        
        for i, letter in enumerate(guess):
            if letter == answer[i]:
                word_color[i] = green
            elif letter in answer:
                word_color[i] = yellow
            else:
                word_color[i] = gray
                
        list(guess)
        
        for i in range(word_length):
            word_space[i] = font.render(guess[i], True, white) #rendering word onto screen
            #for each turn/guess, will want to draw word lower down by 80, first one is 50 from top
            #sqr is 50x50
            sqr_graphic = pygame.Rect(60 + spacing, 50 + (turns*80), 50, 50)
            pygame.draw.rect(window, word_color[i], sqr_graphic) #if the first letter is green, the square drawn will be green, etc.
            #drawing letters in rectangles
            letter_graphic = (70+spacing, 50 + turns*80)
            window.blit(word_space[i], letter_graphic)
            spacing += 80 #moves next letter/sqr to the right by 80
        
        #win condition
        if word_color == [green, green, green, green, green]:
            return True
        
    def get_stats(self):
        if self.game_count == 0:
            return self.try_count
        return self.try_count / self.game_count

# %%
def run(width, height, main_fps, main_clock, main_window, wordle_game):
    wordle_game.game_count += 1
    
    SCREEN_WIDTH = width
    SCREEN_HEIGHT = height
    FPS = main_fps
    clock = main_clock
    window = main_window
    
    window.fill(white)
    
    manual_guess = ""
    
    print(wordle_game.solution)
    
    word_length = 5
    num_guesses = 6
    for x in range(word_length):
        for y in range(num_guesses):
            sqr_graphic = pygame.Rect(60 + 80*x, 50 + (80*y), 50, 50)
            pygame.draw.rect(window, gray, sqr_graphic, 2) #mode 2: unfilled rectangles
            
    pygame.display.set_caption("MANUAL WORDLE")
    
    turns = 0
    win = False
    
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
            
            if wordle_game.player_mode == PlayerMode.manual:
            #user has typed in a letter/pressed key
                if event.type == KEYDOWN:
                    #only allowing alphabet options
                    if event.key == pygame.K_a or event.key == pygame.K_b or event.key == pygame.K_c or event.key == pygame.K_d or event.key == pygame.K_e or event.key == pygame.K_f or event.key == pygame.K_g or event.key == pygame.K_h or event.key == pygame.K_i or event.key == pygame.K_j or event.key == pygame.K_k or event.key == pygame.K_l or event.key == pygame.K_m or event.key == pygame.K_n or event.key == pygame.K_o or event.key == pygame.K_p or event.key == pygame.K_q or event.key == pygame.K_r or event.key == pygame.K_s or event.key == pygame.K_t or event.key == pygame.K_u or event.key == pygame.K_v or event.key == pygame.K_w or event.key == pygame.K_x or event.key == pygame.K_y or event.key == pygame.K_z:
                        manual_guess += event.unicode.upper()
    #                 print("adding character")
    #                 print(len(guess))
                    
                    #won game
                    if event.key == K_RETURN and win == True:
                        wordle_game.generate_new_solution()
                        run(SCREEN_WIDTH, SCREEN_HEIGHT, FPS, clock, window, wordle_game)
                    
                    #ran out of turns
                    if event.key == K_RETURN and turns > 5:
                        wordle_game.generate_new_solution()
                        run(SCREEN_WIDTH, SCREEN_HEIGHT, FPS, clock, window, wordle_game)
                    
                    #user is typing more than five letters
                    if len(manual_guess) > 5:
                        manual_guess = manual_guess[0:5]
                    
                    #user backspaced
                    if event.key == K_BACKSPACE:
                        #removing last one
                        manual_guess = manual_guess[:-1]
                        
                    if event.key == K_RETURN and len(manual_guess) > 4:
                        win = wordle_game.check_guess(turns, wordle_game.solution, manual_guess, window)
                        turns += 1
                        
                        #restart guess
                        manual_guess = ""
                        #black out bottom of screen where guess was previously
                        window.fill(white, (0, 500, 500, 200))

            elif wordle_game.player_mode == PlayerMode.automatic:
#                 time.sleep(1)
                print("we are in automatic")
                print("turns" + str(turns))
                ai_guess = "CRANE"
                if win == True:
                    wordle_game.generate_new_solution()
                    run(SCREEN_WIDTH, SCREEN_HEIGHT, FPS, clock, window, wordle_game)
        
                if turns > 5:
                    wordle_game.generate_new_solution()
                    run(SCREEN_WIDTH, SCREEN_HEIGHT, FPS, clock, window, wordle_game)

                
#                 if len(ai_guess) > 4:
                win = wordle_game.check_guess(turns, wordle_game.solution, ai_guess, window)
                turns += 1
                ai_guess = ""
                    #black out bottom of screen where guess was previously
#                     window.fill(white, (0, 500, 500, 200))
        
        #showing guess at bottom for manual vers
        window.fill(white, (0, 500, 500, 200))
        guess_graphic = font.render(manual_guess, True, black)
        window.blit(guess_graphic, (180, 530))
        
        #end game text
#         print("turns: " + str(turns))
#         print(win)
        if win == True:
            #black out entire screen
            window.fill(white)
            
            win_pos = win_statement.get_rect(center=(SCREEN_WIDTH/2, SCREEN_HEIGHT/2-50))  
            replay_pos = replay_statement.get_rect(center=(SCREEN_WIDTH/2, SCREEN_HEIGHT/2+50)) 
            
            window.blit(win_statement, win_pos)
            window.blit(replay_statement, replay_pos)
#             window.blit(replay_statement, (60, 300))
        elif turns > 5 and win != True:
#             print("you lost")
            window.fill(white)
            lose_pos = lose_statement.get_rect(center=(SCREEN_WIDTH/2, SCREEN_HEIGHT/2-50))            
            replay_pos = replay_statement.get_rect(center=(SCREEN_WIDTH/2, SCREEN_HEIGHT/2+50)) 
            window.blit(lose_statement, lose_pos)
            window.blit(replay_statement, replay_pos)
#             window.blit(replay_statement, (60, 300))
            
        pygame.display.update()
        clock.tick(FPS)

# %%
def main():
    
    SCREEN_WIDTH = 500    
    SCREEN_HEIGHT = 600

    FPS=30
    clock = pygame.time.Clock()
    
    window = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
    window.fill(white)
    
    manual_pos = manual_statement.get_rect(center=(SCREEN_WIDTH/2, SCREEN_HEIGHT/2-50))  
    auto_pos = automatic_statement.get_rect(center=(SCREEN_WIDTH/2, SCREEN_HEIGHT/2+50)) 
            
    window.blit(manual_statement, manual_pos)
    window.blit(automatic_statement, auto_pos)
    
    file1 = open("wordle_solutions.txt","r")
    wordle_solutions = file1.readlines()
    
    manual_bool = None

    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
                
        #user has typed in a letter/pressed key
            if event.type == KEYDOWN:
                #have not yet set automatic or manual mode
                if manual_bool is None:
                    if event.key == pygame.K_a:
                        print("testing automatic")
                        manual_bool = False
                        window.fill(white)
                        normal_pos = normal_statement.get_rect(center=(SCREEN_WIDTH/2, SCREEN_HEIGHT/2-50))  
                        hard_pos = hard_statement.get_rect(center=(SCREEN_WIDTH/2, SCREEN_HEIGHT/2+50))
                        window.blit(normal_statement, normal_pos)
                        window.blit(hard_statement, hard_pos)

                    if event.key == pygame.K_m:
                        print("testing manual")
                        manual_bool = True
                        window.fill(white)
                        normal_pos = normal_statement.get_rect(center=(SCREEN_WIDTH/2, SCREEN_HEIGHT/2-50))  
                        hard_pos = hard_statement.get_rect(center=(SCREEN_WIDTH/2, SCREEN_HEIGHT/2+50))
                        window.blit(normal_statement, normal_pos)
                        window.blit(hard_statement, hard_pos)
                #have set automatic/manual and now need to set normal/hard
                if manual_bool is not None:
                    if event.key == pygame.K_n and manual_bool == True:
                        print("in manual normal mode")
                        wordle_game = Wordle(GameDifficulty.normal, PlayerMode.manual, wordle_solutions)
                        run(SCREEN_WIDTH, SCREEN_HEIGHT, FPS, clock, window, wordle_game)
                    if event.key == pygame.K_n and manual_bool == False:
                        print("in automatic normal mode")
                        wordle_game = Wordle(GameDifficulty.normal, PlayerMode.automatic, wordle_solutions)
                        run(SCREEN_WIDTH, SCREEN_HEIGHT, FPS, clock, window, wordle_game)
                    if event.key == pygame.K_h and manual_bool == True:
                        print("in manual hard mode")
                        wordle_game = Wordle(GameDifficulty.hard, PlayerMode.manual, wordle_solutions)
                        run(SCREEN_WIDTH, SCREEN_HEIGHT, FPS, clock, window, wordle_game)
                    if event.key == pygame.K_h and manual_bool == False:
                        print("in automatic hard mode")
                        wordle_game = Wordle(GameDifficulty.hard, PlayerMode.automatic, wordle_solutions)
                        run(SCREEN_WIDTH, SCREEN_HEIGHT, FPS, clock, window, wordle_game)


        
        pygame.display.update()
        clock.tick(FPS)

# %%
main()
# Out:
# testing automatic
# in automatic normal mode
# CAULK
#
# we are in automatic
# turns0
# Your current ratio is  1.0
# we are in automatic
# turns1
# Your current ratio is  2.0
# we are in automatic
# turns2
# Your current ratio is  3.0
# we are in automatic
# turns3
# Your current ratio is  4.0
# we are in automatic
# turns4
# Your current ratio is  5.0
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# GLOAT
#
# we are in automatic
# turns0
# Your current ratio is  3.5
# we are in automatic
# turns1
# Your current ratio is  4.0
# we are in automatic
# turns2
# Your current ratio is  4.5
# we are in automatic
# turns3
# Your current ratio is  5.0
# we are in automatic
# turns4
# Your current ratio is  5.5
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# LANCE
#
# we are in automatic
# turns0
# Your current ratio is  4.333333333333333
# we are in automatic
# turns1
# Your current ratio is  4.666666666666667
# we are in automatic
# turns2
# Your current ratio is  5.0
# we are in automatic
# turns3
# Your current ratio is  5.333333333333333
# we are in automatic
# turns4
# Your current ratio is  5.666666666666667
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# EMBED
#
# we are in automatic
# turns0
# Your current ratio is  4.75
# we are in automatic
# turns1
# Your current ratio is  5.0
# we are in automatic
# turns2
# Your current ratio is  5.25
# we are in automatic
# turns3
# Your current ratio is  5.5
# we are in automatic
# turns4
# Your current ratio is  5.75
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# MUSKY
#
# we are in automatic
# turns0
# Your current ratio is  5.0
# we are in automatic
# turns1
# Your current ratio is  5.2
# we are in automatic
# turns2
# Your current ratio is  5.4
# we are in automatic
# turns3
# Your current ratio is  5.6
# we are in automatic
# turns4
# Your current ratio is  5.8
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# BOOTY
#
# we are in automatic
# turns0
# Your current ratio is  5.166666666666667
# we are in automatic
# turns1
# Your current ratio is  5.333333333333333
# we are in automatic
# turns2
# Your current ratio is  5.5
# we are in automatic
# turns3
# Your current ratio is  5.666666666666667
# we are in automatic
# turns4
# Your current ratio is  5.833333333333333
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# WACKY
#
# we are in automatic
# turns0
# Your current ratio is  5.285714285714286
# we are in automatic
# turns1
# Your current ratio is  5.428571428571429
# we are in automatic
# turns2
# Your current ratio is  5.571428571428571
# we are in automatic
# turns3
# Your current ratio is  5.714285714285714
# we are in automatic
# turns4
# Your current ratio is  5.857142857142857
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# RISKY
#
# we are in automatic
# turns0
# Your current ratio is  5.375
# we are in automatic
# turns1
# Your current ratio is  5.5
# we are in automatic
# turns2
# Your current ratio is  5.625
# we are in automatic
# turns3
# Your current ratio is  5.75
# we are in automatic
# turns4
# Your current ratio is  5.875
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# GROSS
#
# we are in automatic
# turns0
# Your current ratio is  5.444444444444445
# we are in automatic
# turns1
# Your current ratio is  5.555555555555555
# we are in automatic
# turns2
# Your current ratio is  5.666666666666667
# we are in automatic
# turns3
# Your current ratio is  5.777777777777778
# we are in automatic
# turns4
# Your current ratio is  5.888888888888889
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# SLEEK
#
# we are in automatic
# turns0
# Your current ratio is  5.5
# we are in automatic
# turns1
# Your current ratio is  5.6
# we are in automatic
# turns2
# Your current ratio is  5.7
# we are in automatic
# turns3
# Your current ratio is  5.8
# we are in automatic
# turns4
# Your current ratio is  5.9
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# AHEAD
#
# we are in automatic
# turns0
# Your current ratio is  5.545454545454546
# we are in automatic
# turns1
# Your current ratio is  5.636363636363637
# we are in automatic
# turns2
# Your current ratio is  5.7272727272727275
# we are in automatic
# turns3
# Your current ratio is  5.818181818181818
# we are in automatic
# turns4
# Your current ratio is  5.909090909090909
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# APPLE
#
# we are in automatic
# turns0
# Your current ratio is  5.583333333333333
# we are in automatic
# turns1
# Your current ratio is  5.666666666666667
# we are in automatic
# turns2
# Your current ratio is  5.75
# we are in automatic
# turns3
# Your current ratio is  5.833333333333333
# we are in automatic
# turns4
# Your current ratio is  5.916666666666667
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# AMBLE
#
# we are in automatic
# turns0
# Your current ratio is  5.615384615384615
# we are in automatic
# turns1
# Your current ratio is  5.6923076923076925
# we are in automatic
# turns2
# Your current ratio is  5.769230769230769
# we are in automatic
# turns3
# Your current ratio is  5.846153846153846
# we are in automatic
# turns4
# Your current ratio is  5.923076923076923
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# GAYLY
#
# we are in automatic
# turns0
# Your current ratio is  5.642857142857143
# we are in automatic
# turns1
# Your current ratio is  5.714285714285714
# we are in automatic
# turns2
# Your current ratio is  5.785714285714286
# we are in automatic
# turns3
# Your current ratio is  5.857142857142857
# we are in automatic
# turns4
# Your current ratio is  5.928571428571429
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# QUASI
#
# we are in automatic
# turns0
# Your current ratio is  5.666666666666667
# we are in automatic
# turns1
# Your current ratio is  5.733333333333333
# we are in automatic
# turns2
# Your current ratio is  5.8
# we are in automatic
# turns3
# Your current ratio is  5.866666666666666
# we are in automatic
# turns4
# Your current ratio is  5.933333333333334
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# ALLAY
#
# we are in automatic
# turns0
# Your current ratio is  5.6875
# we are in automatic
# turns1
# Your current ratio is  5.75
# we are in automatic
# turns2
# Your current ratio is  5.8125
# we are in automatic
# turns3
# Your current ratio is  5.875
# we are in automatic
# turns4
# Your current ratio is  5.9375
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# HUSSY
#
# we are in automatic
# turns0
# Your current ratio is  5.705882352941177
# we are in automatic
# turns1
# Your current ratio is  5.764705882352941
# we are in automatic
# turns2
# Your current ratio is  5.823529411764706
# we are in automatic
# turns3
# Your current ratio is  5.882352941176471
# we are in automatic
# turns4
# Your current ratio is  5.9411764705882355
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# CONDO
#
# we are in automatic
# turns0
# Your current ratio is  5.722222222222222
# we are in automatic
# turns1
# Your current ratio is  5.777777777777778
# we are in automatic
# turns2
# Your current ratio is  5.833333333333333
# we are in automatic
# turns3
# Your current ratio is  5.888888888888889
# we are in automatic
# turns4
# Your current ratio is  5.944444444444445
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# FOGGY
#
# we are in automatic
# turns0
# Your current ratio is  5.7368421052631575
# we are in automatic
# turns1
# Your current ratio is  5.7894736842105265
# we are in automatic
# turns2
# Your current ratio is  5.842105263157895
# we are in automatic
# turns3
# Your current ratio is  5.894736842105263
# we are in automatic
# turns4
# Your current ratio is  5.947368421052632
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# THYME
#
# we are in automatic
# turns0
# Your current ratio is  5.75
# we are in automatic
# turns1
# Your current ratio is  5.8
# we are in automatic
# turns2
# Your current ratio is  5.85
# we are in automatic
# turns3
# Your current ratio is  5.9
# we are in automatic
# turns4
# Your current ratio is  5.95
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# GODLY
#
# we are in automatic
# turns0
# Your current ratio is  5.761904761904762
# we are in automatic
# turns1
# Your current ratio is  5.809523809523809
# we are in automatic
# turns2
# Your current ratio is  5.857142857142857
# we are in automatic
# turns3
# Your current ratio is  5.904761904761905
# we are in automatic
# turns4
# Your current ratio is  5.9523809523809526
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# ENTER
#
# we are in automatic
# turns0
# Your current ratio is  5.7727272727272725
# we are in automatic
# turns1
# Your current ratio is  5.818181818181818
# we are in automatic
# turns2
# Your current ratio is  5.863636363636363
# we are in automatic
# turns3
# Your current ratio is  5.909090909090909
# we are in automatic
# turns4
# Your current ratio is  5.954545454545454
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# BUILD
#
# we are in automatic
# turns0
# Your current ratio is  5.782608695652174
# we are in automatic
# turns1
# Your current ratio is  5.826086956521739
# we are in automatic
# turns2
# Your current ratio is  5.869565217391305
# we are in automatic
# turns3
# Your current ratio is  5.913043478260869
# we are in automatic
# turns4
# Your current ratio is  5.956521739130435
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# SHIFT
#
# we are in automatic
# turns0
# Your current ratio is  5.791666666666667
# we are in automatic
# turns1
# Your current ratio is  5.833333333333333
# we are in automatic
# turns2
# Your current ratio is  5.875
# we are in automatic
# turns3
# Your current ratio is  5.916666666666667
# we are in automatic
# turns4
# Your current ratio is  5.958333333333333
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# HOBBY
#
# we are in automatic
# turns0
# Your current ratio is  5.8
# we are in automatic
# turns1
# Your current ratio is  5.84
# we are in automatic
# turns2
# Your current ratio is  5.88
# we are in automatic
# turns3
# Your current ratio is  5.92
# we are in automatic
# turns4
# Your current ratio is  5.96
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# SWISH
#
# we are in automatic
# turns0
# Your current ratio is  5.8076923076923075
# we are in automatic
# turns1
# Your current ratio is  5.846153846153846
# we are in automatic
# turns2
# Your current ratio is  5.884615384615385
# we are in automatic
# turns3
# Your current ratio is  5.923076923076923
# we are in automatic
# turns4
# Your current ratio is  5.961538461538462
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# ELUDE
#
# we are in automatic
# turns0
# Your current ratio is  5.814814814814815
# we are in automatic
# turns1
# Your current ratio is  5.851851851851852
# we are in automatic
# turns2
# Your current ratio is  5.888888888888889
# we are in automatic
# turns3
# Your current ratio is  5.925925925925926
# we are in automatic
# turns4
# Your current ratio is  5.962962962962963
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# KRILL
#
# we are in automatic
# turns0
# Your current ratio is  5.821428571428571
# we are in automatic
# turns1
# Your current ratio is  5.857142857142857
# we are in automatic
# turns2
# Your current ratio is  5.892857142857143
# we are in automatic
# turns3
# Your current ratio is  5.928571428571429
# we are in automatic
# turns4
# Your current ratio is  5.964285714285714
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# RADAR
#
# we are in automatic
# turns0
# Your current ratio is  5.827586206896552
# we are in automatic
# turns1
# Your current ratio is  5.862068965517241
# we are in automatic
# turns2
# Your current ratio is  5.896551724137931
# we are in automatic
# turns3
# Your current ratio is  5.931034482758621
# we are in automatic
# turns4
# Your current ratio is  5.9655172413793105
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# MILKY
#
# we are in automatic
# turns0
# Your current ratio is  5.833333333333333
# we are in automatic
# turns1
# Your current ratio is  5.866666666666666
# we are in automatic
# turns2
# Your current ratio is  5.9
# we are in automatic
# turns3
# Your current ratio is  5.933333333333334
# we are in automatic
# turns4
# Your current ratio is  5.966666666666667
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# BIBLE
#
# we are in automatic
# turns0
# Your current ratio is  5.838709677419355
# we are in automatic
# turns1
# Your current ratio is  5.870967741935484
# we are in automatic
# turns2
# Your current ratio is  5.903225806451613
# we are in automatic
# turns3
# Your current ratio is  5.935483870967742
# we are in automatic
# turns4
# Your current ratio is  5.967741935483871
# we are in automatic
# turns5
# Your current ratio is  6.0
# we are in automatic
# turns6
# WHARF
#
# we are in automatic
# turns0
# Your current ratio is  5.84375
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/vivian/opt/anaconda3/envs/wordle_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3377: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
