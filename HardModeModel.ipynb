# %%
import random
import time
import collections
class HardModeModel:
    def __init__(self, possible_words, starting_word, final_answer, word_frequencies, all_words):
        self.current_guess = starting_word
        self.final_answer = final_answer
        self.gray_letters = []
        self.all_guesses = possible_words
        self.possible_guesses = possible_words
        self.freq_scoring = {'q': 26, 'j': 25, 'z': 24, 'x': 23, 'v': 22, 'w': 21, 'f': 20, 'k': 19, 'b': 18, 'g': 17, 'm': 16, 'h': 15, 'y': 14, 'p': 13, 'u': 12, 'c': 11, 'n': 10, 'd': 9, 'l': 8, 'i': 7, 't': 6, 'o': 5, 'r': 4, 'a': 3, 's': 2, 'e': 1}
        self.word_freqs = word_frequencies
        
    # This function determines if a guess is valid given the feedback that's been given from guesses 
    # till this point yellow letters is a list of all letters of the guess that are correct but in the wrong 
    # position green letters is a tuple list of all leters of the guess that are in the correct position and 
    # spot with the letters respective position in the tuple list, example green_letters = [('h',2), ('e',3)]
    def _valid_guess(self, guess, green_letters, yellow_letters, gray_letters):
        for letter_tuple in yellow_letters:
            if letter_tuple[0] not in guess or guess[letter_tuple[1]] == letter_tuple[0]:
                return False
        for letter_tuple in green_letters:
            if guess[letter_tuple[1]] != letter_tuple[0]:
                return False
        for letter in gray_letters:
            if letter in guess:
                return False
        return True
    
    # This function provides feedback for a guess given some answer, the notation of the feedback is seen below
    # For a given word heart, the notation used throughout the model is as follows
    # Each letter is given a score of 0, 1, or 2. 0 means that the letter does not exist in the correct answer. 
    # 1 means the letter is yellow, correct letter wrong spot. 2 menas the lettter is green, correct letter and correct
    # spot. if the answer is harsh and our guess is heart, then the resulting notation would be:
    # [('h',2),('e',0),('a',1),('r',0), ('t',0)]
    def _score_guess(self, answer, guess):
        guess_feedback = []
        for i in range(5):
            if guess[i] == answer[i]:
                guess_feedback.append((guess[i],2))
            elif guess[i] in answer:
                guess_feedback.append((guess[i],1))
            else:
                guess_feedback.append((guess[i],0))
        return guess_feedback
    # This function creates a frequency scoring 
    def _score_frequency(self, word):
        score = 0
        for letter in word:
            score += self.freq_scoring[letter]
        return score
    # This function takes feedback in the above form and converts it into a list of green, yellow, and 
    # gray letters green letters and yellow letters are stored in tuples of the letter and their index within 
    # the word gray letters are simply a list of all gray letters
    def _get_green_yellow_gray_letters(self, guess_feedback):
        green_letters = []
        yellow_letters = []
        gray_letters = []
        for index, feedback_tuple in enumerate(guess_feedback):
            if feedback_tuple[1] == 2:
                green_letters.append((feedback_tuple[0], index))
            elif feedback_tuple[1] == 1:
                yellow_letters.append((feedback_tuple[0], index))
            else:
                gray_letters.append(feedback_tuple[0])
        return green_letters, yellow_letters, gray_letters
    def _word_freq_score(self, word):
        score = 1/self.word_freqs[word]
        return score
    
    # This is the main wordle prediction algorithm. It takes in the final_answer we are trying to find, 
    # a current working list of possible guesses, a list of gray letters, and the current guess we have just made
    # It then finds the next guess using a greedy min-max approach 
    def next_guess(self):
        
        # Getting feedback on our current guess based on the answer we're working towards 
        guess_feedback = self._score_guess(self.final_answer, self.current_guess)
        green_letters, yellow_letters, current_gray_letters = self._get_green_yellow_gray_letters(guess_feedback)
        new_gray_letters = self.gray_letters + current_gray_letters
        new_possible_guesses = []
        
        # Based on the feedback of the guess, narrowing down our list of possible guesses we can chose from
        for guess in self.possible_guesses:
            if self._valid_guess(guess, green_letters, yellow_letters, new_gray_letters):
                new_possible_guesses.append(guess)
        self.possible_guesses = new_possible_guesses

        # Creating the guess answer matrix. This matrix is a matrix of all the possible words by all the possible words.
        # The rows represent the possible guesses and the columns represent the possible answers
        # The value at (guess, answer) represents the number of new possible guesses that exist if we guessed 'guess'
        # and the final answer we were working towards was 'answer'.
        guess_answer_matrix = {}
        for guess in self.possible_guesses:
            guess_answer_matrix[guess] = {}
            for answer in self.possible_guesses:
                guess_feedback = self._score_guess(answer,guess)
                curr_green_letters, curr_yellow_letters, curr_gray_letters = self._get_green_yellow_gray_letters(guess_feedback)
                valid_guesses = 0
                new_possible_guesses = self.possible_guesses.copy()
                new_possible_guesses.remove(guess)
                for option in new_possible_guesses:
                    if self._valid_guess(option,curr_green_letters,curr_yellow_letters, curr_gray_letters):
                        valid_guesses += 1
                guess_answer_matrix[guess][answer] = valid_guesses
        
        # Given this matrix of possible guesses for each guess, answer pair, we find the guess that minimizes the 
        # maximum new possible guesses across all possible answers. This is a greedy minmax approach
        max_guess_dict = {}
        for guess in guess_answer_matrix:
            max_possible_guesses = max(guess_answer_matrix[guess].values())
            max_guess_dict.setdefault(max_possible_guesses,[]).append(guess)
        
        first_val = max_guess_dict[list(max_guess_dict.keys())[0]]
        if len(max_guess_dict) == 1 and len(first_val) > 2:
            
            first_test_word = first_val[0]
            second_test_word = first_val[1]
            difference_index = 0
            for i in range(5):
                if first_test_word[i] != second_test_word[i]:
                    difference_index = i
            possible_letters = []
            for word in first_val:
                possible_letters.append(word[difference_index])
            max_letters = 0
            min_guess = ''
            for word in self.all_guesses:
                count = 0
                for letter in possible_letters:
                    if letter in word:
                        count += 1
                if count > max_letters:
                    min_guess = word
                    max_letters = count
            self.current_guess = min_guess

#             min_guess_score = 3000
#             min_guess = ''
#             for key in max_guess_dict:
# #                 for guess in max_guess_dict[key]:
# #                     guess_score = self._score_frequency(guess)
# #                     if guess_score < min_guess_score:
# #                         min_guess_score = guess_score
# #                         min_guess = guess
                
#                 for guess in max_guess_dict[key]:
#                         guess_score = self._word_freq_score(guess)
#                         if guess_score < min_guess_score:
#                             min_guess_score = guess_score
#                             min_guess = guess
            self.current_guess = min_guess
            

        else: 
            self.current_guess = max_guess_dict[min(max_guess_dict.keys())][0]
        
                
        return self.current_guess

# %%
#Testing framework 

# Initializing list of all possible wordle guesses
possible_words = []
with open('wordle_solutions.txt') as file:
    for line in file:
        possible_words.append(line.replace('\n',''))
        
all_words = []
with open('common.txt') as file:
    for line in file:
        all_words.append(line.replace('\n',''))
        
word_freqs = {}
with open('word_frequency.txt') as file:
    for line in file:
        text = line.replace('\n','')
        freqs = text.split(' ')[0].split('\t')
        word_freqs[freqs[0]] = int(freqs[1])
        
times = []
counts = []
for word in possible_words[0:500]:
    start = time.time()
    guess = 'crane'
    final_answer = word
    model = HardModeModel(possible_words, guess, final_answer, word_freqs, all_words)
    count = 1
    guesses = [guess]
    while guess != final_answer:
        guess = model.next_guess()
        guesses.append(guess)
        count += 1
    counts.append(count)
    end = time.time()
    final_time= end - start
    times.append(final_time)
    print('Final Answer: ' + str(final_answer) + ', Count: ' + str(count) + ', Guesses: ' + str(guesses) + ', Time: ' + str(final_time) + ' seconds')
print('Average guesses per game: ' + str(sum(counts)/len(counts)))
print('Average time per game: ' + str(sum(times)/len(times)))


# guess = 'rates'
# model = HardModeModel(possible_words, guess, 'moist', word_freqs, all_words) 
# guesses = ['rates']
# while guess != 'moist':
#     guess = model.next_guess()
#     guesses.append(guess)
# print(guesses)
# Out:
# Final Answer: rebus, Count: 4, Guesses: ['crane', 'retro', 'reply', 'rebus'], Time: 0.5315136909484863 seconds
# Final Answer: boost, Count: 4, Guesses: ['crane', 'lousy', 'moist', 'boost'], Time: 3.7080929279327393 seconds
# Final Answer: truss, Count: 4, Guesses: ['crane', 'drift', 'pushy', 'truss'], Time: 0.03983306884765625 seconds
# Final Answer: siege, Count: 3, Guesses: ['crane', 'slide', 'siege'], Time: 0.2838871479034424 seconds
# Final Answer: tiger, Count: 3, Guesses: ['crane', 'retro', 'tiger'], Time: 0.5325300693511963 seconds
# Final Answer: banal, Count: 3, Guesses: ['crane', 'manly', 'banal'], Time: 0.036119699478149414 seconds
# Final Answer: slump, Count: 4, Guesses: ['crane', 'lousy', 'skulk', 'slump'], Time: 3.694369077682495 seconds
# Final Answer: crank, Count: 2, Guesses: ['crane', 'crank'], Time: 0.0005297660827636719 seconds
# Final Answer: gorge, Count: 4, Guesses: ['crane', 'surge', 'merge', 'gorge'], Time: 0.0181581974029541 seconds
# Final Answer: query, Count: 3, Guesses: ['crane', 'retro', 'query'], Time: 0.5328309535980225 seconds
# Final Answer: drink, Count: 3, Guesses: ['crane', 'grind', 'drink'], Time: 0.0019140243530273438 seconds
# Final Answer: favor, Count: 3, Guesses: ['crane', 'foray', 'favor'], Time: 0.06399178504943848 seconds
# Final Answer: abbey, Count: 3, Guesses: ['crane', 'steal', 'abbey'], Time: 0.030014991760253906 seconds
# Final Answer: tangy, Count: 4, Guesses: ['crane', 'manly', 'dandy', 'tangy'], Time: 0.03586983680725098 seconds
# Final Answer: panic, Count: 2, Guesses: ['crane', 'panic'], Time: 0.0005049705505371094 seconds
# Final Answer: solar, Count: 4, Guesses: ['crane', 'foray', 'slump', 'solar'], Time: 0.06412291526794434 seconds
# Final Answer: shire, Count: 4, Guesses: ['crane', 'surge', 'point', 'shire'], Time: 0.019033193588256836 seconds
# Final Answer: proxy, Count: 4, Guesses: ['crane', 'drift', 'groom', 'proxy'], Time: 0.039587974548339844 seconds
# Final Answer: point, Count: 3, Guesses: ['crane', 'stung', 'point'], Time: 0.05040884017944336 seconds
# Final Answer: robot, Count: 3, Guesses: ['crane', 'torus', 'robot'], Time: 0.16384100914001465 seconds
# Final Answer: tiara, Count: 4, Guesses: ['crane', 'shard', 'quart', 'tiara'], Time: 0.004914999008178711 seconds
# Final Answer: crept, Count: 4, Guesses: ['crane', 'creed', 'boost', 'crept'], Time: 0.00151824951171875 seconds
# Final Answer: bayou, Count: 3, Guesses: ['crane', 'aptly', 'bayou'], Time: 0.5915548801422119 seconds
# Final Answer: atoll, Count: 3, Guesses: ['crane', 'aptly', 'atoll'], Time: 0.590540885925293 seconds
# Final Answer: manor, Count: 3, Guesses: ['crane', 'rayon', 'manor'], Time: 0.0011518001556396484 seconds
# Final Answer: creak, Count: 2, Guesses: ['crane', 'creak'], Time: 0.0004680156707763672 seconds
# Final Answer: showy, Count: 3, Guesses: ['crane', 'lousy', 'showy'], Time: 3.700701951980591 seconds
# Final Answer: phase, Count: 3, Guesses: ['crane', 'slate', 'phase'], Time: 0.025155067443847656 seconds
# Final Answer: froth, Count: 3, Guesses: ['crane', 'drift', 'froth'], Time: 0.039093017578125 seconds
# Final Answer: depth, Count: 3, Guesses: ['crane', 'depot', 'depth'], Time: 0.45992088317871094 seconds
# Final Answer: gloom, Count: 4, Guesses: ['crane', 'lousy', 'bloom', 'gloom'], Time: 3.700438976287842 seconds
# Final Answer: flood, Count: 4, Guesses: ['crane', 'lousy', 'bloom', 'flood'], Time: 3.7164433002471924 seconds
# Final Answer: trait, Count: 3, Guesses: ['crane', 'graft', 'trait'], Time: 0.00493621826171875 seconds
# Final Answer: girth, Count: 3, Guesses: ['crane', 'torus', 'girth'], Time: 0.16461515426635742 seconds
# Final Answer: piety, Count: 3, Guesses: ['crane', 'depot', 'piety'], Time: 0.4593191146850586 seconds
# Final Answer: payer, Count: 5, Guesses: ['crane', 'later', 'wager', 'parer', 'payer'], Time: 0.050752878189086914 seconds
# Final Answer: goose, Count: 4, Guesses: ['crane', 'slide', 'moose', 'goose'], Time: 0.28482985496520996 seconds
# Final Answer: float, Count: 3, Guesses: ['crane', 'aptly', 'float'], Time: 0.5895240306854248 seconds
# Final Answer: donor, Count: 3, Guesses: ['crane', 'thorn', 'donor'], Time: 0.001767873764038086 seconds
# Final Answer: atone, Count: 2, Guesses: ['crane', 'atone'], Time: 0.00048160552978515625 seconds
# Final Answer: primo, Count: 4, Guesses: ['crane', 'drift', 'prism', 'primo'], Time: 0.039839982986450195 seconds
# Final Answer: apron, Count: 3, Guesses: ['crane', 'rayon', 'apron'], Time: 0.0011048316955566406 seconds
# Final Answer: blown, Count: 3, Guesses: ['crane', 'synod', 'blown'], Time: 0.05514788627624512 seconds
# Final Answer: cacao, Count: 3, Guesses: ['crane', 'cacti', 'cacao'], Time: 0.0016629695892333984 seconds
# Final Answer: loser, Count: 3, Guesses: ['crane', 'retro', 'loser'], Time: 0.5355920791625977 seconds
# Final Answer: input, Count: 4, Guesses: ['crane', 'synod', 'unfit', 'input'], Time: 0.05611920356750488 seconds
# Final Answer: gloat, Count: 4, Guesses: ['crane', 'aptly', 'float', 'gloat'], Time: 0.5917890071868896 seconds
# Final Answer: awful, Count: 4, Guesses: ['crane', 'aptly', 'aloud', 'awful'], Time: 0.5936908721923828 seconds
# Final Answer: brink, Count: 3, Guesses: ['crane', 'grind', 'brink'], Time: 0.0019309520721435547 seconds
# Final Answer: smite, Count: 3, Guesses: ['crane', 'slide', 'smite'], Time: 0.2851841449737549 seconds
# Final Answer: beady, Count: 4, Guesses: ['crane', 'exalt', 'butch', 'beady'], Time: 0.0027799606323242188 seconds
# Final Answer: rusty, Count: 3, Guesses: ['crane', 'torus', 'rusty'], Time: 0.1639559268951416 seconds
# Final Answer: retro, Count: 2, Guesses: ['crane', 'retro'], Time: 0.5327770709991455 seconds
# Final Answer: droll, Count: 4, Guesses: ['crane', 'drift', 'drool', 'droll'], Time: 0.039344072341918945 seconds
# Final Answer: gawky, Count: 4, Guesses: ['crane', 'aptly', 'daisy', 'gawky'], Time: 0.5917339324951172 seconds
# Final Answer: hutch, Count: 4, Guesses: ['crane', 'stick', 'butch', 'hutch'], Time: 0.03760480880737305 seconds
# Final Answer: pinto, Count: 4, Guesses: ['crane', 'synod', 'lingo', 'pinto'], Time: 0.05533599853515625 seconds
# Final Answer: gaily, Count: 4, Guesses: ['crane', 'aptly', 'sadly', 'gaily'], Time: 0.5913031101226807 seconds
# Final Answer: egret, Count: 4, Guesses: ['crane', 'retro', 'tiger', 'egret'], Time: 0.533897876739502 seconds
# Final Answer: lilac, Count: 3, Guesses: ['crane', 'mocha', 'lilac'], Time: 0.006649971008300781 seconds
# Final Answer: sever, Count: 3, Guesses: ['crane', 'retro', 'sever'], Time: 0.5362951755523682 seconds
# Final Answer: field, Count: 4, Guesses: ['crane', 'depot', 'edify', 'field'], Time: 0.4597351551055908 seconds
# Final Answer: fluff, Count: 4, Guesses: ['crane', 'lousy', 'bluff', 'fluff'], Time: 3.705479860305786 seconds
# Final Answer: hydro, Count: 4, Guesses: ['crane', 'torus', 'vigor', 'hydro'], Time: 0.1631009578704834 seconds
# Final Answer: flack, Count: 4, Guesses: ['crane', 'scald', 'black', 'flack'], Time: 0.0013709068298339844 seconds
# Final Answer: agape, Count: 3, Guesses: ['crane', 'slate', 'agape'], Time: 0.024973154067993164 seconds
# Final Answer: wench, Count: 2, Guesses: ['crane', 'wench'], Time: 0.000408172607421875 seconds
# Final Answer: voice, Count: 4, Guesses: ['crane', 'spice', 'would', 'voice'], Time: 0.0012049674987792969 seconds
# Final Answer: stead, Count: 4, Guesses: ['crane', 'steal', 'drink', 'stead'], Time: 0.030765771865844727 seconds
# Final Answer: stalk, Count: 3, Guesses: ['crane', 'flash', 'stalk'], Time: 0.039112091064453125 seconds
# Final Answer: berth, Count: 4, Guesses: ['crane', 'retro', 'light', 'berth'], Time: 0.5343897342681885 seconds
# Final Answer: madam, Count: 4, Guesses: ['crane', 'aptly', 'sigma', 'madam'], Time: 0.5918149948120117 seconds
# Final Answer: night, Count: 4, Guesses: ['crane', 'synod', 'unfit', 'night'], Time: 0.05584383010864258 seconds
# Final Answer: bland, Count: 3, Guesses: ['crane', 'stank', 'bland'], Time: 0.0022950172424316406 seconds
# Final Answer: smear, Count: 3, Guesses: ['crane', 'later', 'smear'], Time: 0.04905509948730469 seconds
# Final Answer: unfit, Count: 3, Guesses: ['crane', 'synod', 'unfit'], Time: 0.055181026458740234 seconds
# Final Answer: patty, Count: 3, Guesses: ['crane', 'aptly', 'patty'], Time: 0.5949380397796631 seconds
# Final Answer: cling, Count: 3, Guesses: ['crane', 'clink', 'cling'], Time: 0.0006201267242431641 seconds
# Final Answer: glean, Count: 4, Guesses: ['crane', 'eaten', 'began', 'glean'], Time: 0.004155158996582031 seconds
# Final Answer: label, Count: 4, Guesses: ['crane', 'steal', 'bagel', 'label'], Time: 0.03178215026855469 seconds
# Final Answer: hunky, Count: 3, Guesses: ['crane', 'synod', 'hunky'], Time: 0.05646681785583496 seconds
# Final Answer: khaki, Count: 3, Guesses: ['crane', 'flash', 'khaki'], Time: 0.03935599327087402 seconds
# Final Answer: poker, Count: 5, Guesses: ['crane', 'retro', 'loser', 'homer', 'poker'], Time: 0.5384950637817383 seconds
# Final Answer: gruel, Count: 4, Guesses: ['crane', 'pried', 'solar', 'gruel'], Time: 0.004130125045776367 seconds
# Final Answer: twice, Count: 4, Guesses: ['crane', 'spice', 'would', 'twice'], Time: 0.0012531280517578125 seconds
# Final Answer: twang, Count: 4, Guesses: ['crane', 'stank', 'tiger', 'twang'], Time: 0.0025501251220703125 seconds
# Final Answer: shrug, Count: 3, Guesses: ['crane', 'torus', 'shrug'], Time: 0.16608214378356934 seconds
# Final Answer: treat, Count: 3, Guesses: ['crane', 'tread', 'treat'], Time: 0.0007631778717041016 seconds
# Final Answer: unlit, Count: 4, Guesses: ['crane', 'synod', 'unfit', 'unlit'], Time: 0.05609488487243652 seconds
# Final Answer: waste, Count: 3, Guesses: ['crane', 'table', 'waste'], Time: 0.03412914276123047 seconds
# Final Answer: merit, Count: 4, Guesses: ['crane', 'retro', 'light', 'merit'], Time: 0.5347630977630615 seconds
# Final Answer: woven, Count: 4, Guesses: ['crane', 'olden', 'skimp', 'woven'], Time: 0.058508872985839844 seconds
# Final Answer: octal, Count: 3, Guesses: ['crane', 'mocha', 'octal'], Time: 0.006647825241088867 seconds
# Final Answer: needy, Count: 3, Guesses: ['crane', 'olden', 'needy'], Time: 0.05779409408569336 seconds
# Final Answer: clown, Count: 3, Guesses: ['crane', 'cinch', 'clown'], Time: 0.0005869865417480469 seconds
# Final Answer: widow, Count: 4, Guesses: ['crane', 'lousy', 'pivot', 'widow'], Time: 3.728631019592285 seconds
# Final Answer: irony, Count: 3, Guesses: ['crane', 'grind', 'irony'], Time: 0.002012968063354492 seconds
# Final Answer: ruder, Count: 3, Guesses: ['crane', 'retro', 'ruder'], Time: 0.5325796604156494 seconds
# Final Answer: gauze, Count: 3, Guesses: ['crane', 'table', 'gauze'], Time: 0.03456997871398926 seconds
# Final Answer: chief, Count: 3, Guesses: ['crane', 'chest', 'chief'], Time: 0.0011229515075683594 seconds
# Final Answer: onset, Count: 3, Guesses: ['crane', 'olden', 'onset'], Time: 0.05825018882751465 seconds
# Final Answer: prize, Count: 3, Guesses: ['crane', 'trope', 'prize'], Time: 0.003815889358520508 seconds
# Final Answer: fungi, Count: 4, Guesses: ['crane', 'synod', 'ninth', 'fungi'], Time: 0.05539703369140625 seconds
# Final Answer: charm, Count: 2, Guesses: ['crane', 'charm'], Time: 0.0005481243133544922 seconds
# Final Answer: gully, Count: 4, Guesses: ['crane', 'lousy', 'badge', 'gully'], Time: 3.7183051109313965 seconds
# Final Answer: inter, Count: 2, Guesses: ['crane', 'inter'], Time: 0.007497072219848633 seconds
# Final Answer: whoop, Count: 4, Guesses: ['crane', 'lousy', 'pivot', 'whoop'], Time: 3.7114970684051514 seconds
# Final Answer: taunt, Count: 3, Guesses: ['crane', 'taint', 'taunt'], Time: 0.0037589073181152344 seconds
# Final Answer: leery, Count: 4, Guesses: ['crane', 'retro', 'merry', 'leery'], Time: 0.5350768566131592 seconds
# Final Answer: class, Count: 3, Guesses: ['crane', 'clasp', 'class'], Time: 0.0013289451599121094 seconds
# Final Answer: theme, Count: 4, Guesses: ['crane', 'slide', 'butte', 'theme'], Time: 0.28757190704345703 seconds
# Final Answer: lofty, Count: 4, Guesses: ['crane', 'lousy', 'blast', 'lofty'], Time: 3.7147481441497803 seconds
# Final Answer: tibia, Count: 4, Guesses: ['crane', 'aptly', 'waist', 'tibia'], Time: 0.5942161083221436 seconds
# Final Answer: booze, Count: 4, Guesses: ['crane', 'slide', 'butte', 'booze'], Time: 0.28646183013916016 seconds
# Final Answer: alpha, Count: 3, Guesses: ['crane', 'aptly', 'alpha'], Time: 0.59755539894104 seconds
# Final Answer: thyme, Count: 5, Guesses: ['crane', 'slide', 'butte', 'theme', 'thyme'], Time: 0.2879180908203125 seconds
# Final Answer: eclat, Count: 3, Guesses: ['crane', 'decay', 'eclat'], Time: 0.0006618499755859375 seconds
# Final Answer: doubt, Count: 4, Guesses: ['crane', 'lousy', 'light', 'doubt'], Time: 3.742324113845825 seconds
# Final Answer: parer, Count: 4, Guesses: ['crane', 'later', 'wager', 'parer'], Time: 0.05196785926818848 seconds
# Final Answer: chute, Count: 4, Guesses: ['crane', 'choke', 'chide', 'chute'], Time: 0.0013098716735839844 seconds
# Final Answer: stick, Count: 2, Guesses: ['crane', 'stick'], Time: 0.037577152252197266 seconds
# Final Answer: trice, Count: 3, Guesses: ['crane', 'point', 'trice'], Time: 0.0008029937744140625 seconds
# Final Answer: alike, Count: 3, Guesses: ['crane', 'table', 'alike'], Time: 0.035199880599975586 seconds
# Final Answer: sooth, Count: 4, Guesses: ['crane', 'lousy', 'month', 'sooth'], Time: 3.7476861476898193 seconds
# Final Answer: recap, Count: 2, Guesses: ['crane', 'recap'], Time: 0.0004100799560546875 seconds
# Final Answer: saint, Count: 4, Guesses: ['crane', 'taint', 'spoof', 'saint'], Time: 0.004122257232666016 seconds
# Final Answer: liege, Count: 3, Guesses: ['crane', 'slide', 'liege'], Time: 0.2939770221710205 seconds
# Final Answer: glory, Count: 4, Guesses: ['crane', 'torus', 'vigor', 'glory'], Time: 0.17125606536865234 seconds
# Final Answer: grate, Count: 2, Guesses: ['crane', 'grate'], Time: 0.0013909339904785156 seconds
# Final Answer: admit, Count: 4, Guesses: ['crane', 'aptly', 'about', 'admit'], Time: 0.5954799652099609 seconds
# Final Answer: brisk, Count: 4, Guesses: ['crane', 'drift', 'prism', 'brisk'], Time: 0.039910316467285156 seconds
# Final Answer: soggy, Count: 3, Guesses: ['crane', 'lousy', 'soggy'], Time: 3.7125518321990967 seconds
# Final Answer: usurp, Count: 3, Guesses: ['crane', 'torus', 'usurp'], Time: 0.1650068759918213 seconds
# Final Answer: scald, Count: 2, Guesses: ['crane', 'scald'], Time: 0.0013668537139892578 seconds
# Final Answer: scorn, Count: 2, Guesses: ['crane', 'scorn'], Time: 0.00039887428283691406 seconds
# Final Answer: leave, Count: 3, Guesses: ['crane', 'slate', 'leave'], Time: 0.02496480941772461 seconds
# Final Answer: twine, Count: 3, Guesses: ['crane', 'shone', 'twine'], Time: 0.001428842544555664 seconds
# Final Answer: sting, Count: 3, Guesses: ['crane', 'stung', 'sting'], Time: 0.05163884162902832 seconds
# Final Answer: bough, Count: 4, Guesses: ['crane', 'lousy', 'light', 'bough'], Time: 3.7055351734161377 seconds
# Final Answer: marsh, Count: 4, Guesses: ['crane', 'foray', 'whack', 'marsh'], Time: 0.06491804122924805 seconds
# Final Answer: sloth, Count: 4, Guesses: ['crane', 'lousy', 'spoil', 'sloth'], Time: 3.712653160095215 seconds
# Final Answer: dandy, Count: 3, Guesses: ['crane', 'manly', 'dandy'], Time: 0.037172794342041016 seconds
# Final Answer: vigor, Count: 3, Guesses: ['crane', 'torus', 'vigor'], Time: 0.16491317749023438 seconds
# Final Answer: howdy, Count: 4, Guesses: ['crane', 'lousy', 'goody', 'howdy'], Time: 3.708913803100586 seconds
# Final Answer: enjoy, Count: 4, Guesses: ['crane', 'olden', 'nymph', 'enjoy'], Time: 0.058450937271118164 seconds
# Final Answer: valid, Count: 4, Guesses: ['crane', 'aptly', 'shoal', 'valid'], Time: 0.5939791202545166 seconds
# Final Answer: ionic, Count: 3, Guesses: ['crane', 'lunch', 'ionic'], Time: 0.0027768611907958984 seconds
# Final Answer: equal, Count: 4, Guesses: ['crane', 'steal', 'medal', 'equal'], Time: 0.030736207962036133 seconds
# Final Answer: unset, Count: 3, Guesses: ['crane', 'olden', 'unset'], Time: 0.05857110023498535 seconds
# Final Answer: floor, Count: 4, Guesses: ['crane', 'torus', 'vigor', 'floor'], Time: 0.16549205780029297 seconds
# Final Answer: catch, Count: 3, Guesses: ['crane', 'cacti', 'catch'], Time: 0.001741170883178711 seconds
# Final Answer: spade, Count: 4, Guesses: ['crane', 'slate', 'shake', 'spade'], Time: 0.025760650634765625 seconds
# Final Answer: stein, Count: 4, Guesses: ['crane', 'olden', 'input', 'stein'], Time: 0.059005022048950195 seconds
# Final Answer: exist, Count: 4, Guesses: ['crane', 'depot', 'sweet', 'exist'], Time: 0.4617459774017334 seconds
# Final Answer: quirk, Count: 4, Guesses: ['crane', 'torus', 'blurb', 'quirk'], Time: 0.1666398048400879 seconds
# Final Answer: denim, Count: 4, Guesses: ['crane', 'olden', 'needy', 'denim'], Time: 0.0582430362701416 seconds
# Final Answer: grove, Count: 3, Guesses: ['crane', 'trope', 'grove'], Time: 0.003709077835083008 seconds
# Final Answer: spiel, Count: 3, Guesses: ['crane', 'depot', 'spiel'], Time: 0.4624321460723877 seconds
# Final Answer: mummy, Count: 4, Guesses: ['crane', 'lousy', 'dumpy', 'mummy'], Time: 3.709291934967041 seconds
# Final Answer: fault, Count: 3, Guesses: ['crane', 'aptly', 'fault'], Time: 0.5933759212493896 seconds
# Final Answer: foggy, Count: 4, Guesses: ['crane', 'lousy', 'goody', 'foggy'], Time: 3.7070038318634033 seconds
# Final Answer: flout, Count: 3, Guesses: ['crane', 'lousy', 'flout'], Time: 3.7222368717193604 seconds
# Final Answer: carry, Count: 3, Guesses: ['crane', 'cargo', 'carry'], Time: 0.0007450580596923828 seconds
# Final Answer: sneak, Count: 3, Guesses: ['crane', 'eaten', 'sneak'], Time: 0.003988981246948242 seconds
# Final Answer: libel, Count: 4, Guesses: ['crane', 'depot', 'shell', 'libel'], Time: 0.46643781661987305 seconds
# Final Answer: waltz, Count: 4, Guesses: ['crane', 'aptly', 'float', 'waltz'], Time: 0.597815752029419 seconds
# Final Answer: aptly, Count: 2, Guesses: ['crane', 'aptly'], Time: 0.5918979644775391 seconds
# Final Answer: piney, Count: 4, Guesses: ['crane', 'olden', 'unset', 'piney'], Time: 0.057730913162231445 seconds
# Final Answer: inept, Count: 3, Guesses: ['crane', 'olden', 'inept'], Time: 0.057660818099975586 seconds
# Final Answer: aloud, Count: 3, Guesses: ['crane', 'aptly', 'aloud'], Time: 0.5956699848175049 seconds
# Final Answer: photo, Count: 4, Guesses: ['crane', 'lousy', 'pivot', 'photo'], Time: 3.7195849418640137 seconds
# Final Answer: dream, Count: 3, Guesses: ['crane', 'tread', 'dream'], Time: 0.0007231235504150391 seconds
# Final Answer: stale, Count: 3, Guesses: ['crane', 'slate', 'stale'], Time: 0.024898052215576172 seconds
# Final Answer: vomit, Count: 4, Guesses: ['crane', 'lousy', 'froth', 'vomit'], Time: 3.718280792236328 seconds
# Final Answer: ombre, Count: 4, Guesses: ['crane', 'surge', 'fibre', 'ombre'], Time: 0.01860666275024414 seconds
# Final Answer: fanny, Count: 3, Guesses: ['crane', 'taint', 'fanny'], Time: 0.003748178482055664 seconds
# Final Answer: unite, Count: 4, Guesses: ['crane', 'singe', 'unfit', 'unite'], Time: 0.004841804504394531 seconds
# Final Answer: snarl, Count: 2, Guesses: ['crane', 'snarl'], Time: 0.00043487548828125 seconds
# Final Answer: baker, Count: 5, Guesses: ['crane', 'later', 'wager', 'parer', 'baker'], Time: 0.05031394958496094 seconds
# Final Answer: there, Count: 4, Guesses: ['crane', 'surge', 'fibre', 'there'], Time: 0.01826310157775879 seconds
# Final Answer: glyph, Count: 3, Guesses: ['crane', 'lousy', 'glyph'], Time: 3.709926128387451 seconds
# Final Answer: pooch, Count: 4, Guesses: ['crane', 'stick', 'could', 'pooch'], Time: 0.03843116760253906 seconds
# Final Answer: hippy, Count: 4, Guesses: ['crane', 'lousy', 'ditty', 'hippy'], Time: 3.709469795227051 seconds
# Final Answer: spell, Count: 4, Guesses: ['crane', 'depot', 'spiel', 'spell'], Time: 0.4608461856842041 seconds
# Final Answer: folly, Count: 3, Guesses: ['crane', 'lousy', 'folly'], Time: 3.7095539569854736 seconds
# Final Answer: louse, Count: 4, Guesses: ['crane', 'slide', 'could', 'louse'], Time: 0.28637099266052246 seconds
# Final Answer: gulch, Count: 4, Guesses: ['crane', 'stick', 'could', 'gulch'], Time: 0.03810262680053711 seconds
# Final Answer: vault, Count: 4, Guesses: ['crane', 'aptly', 'fault', 'vault'], Time: 0.5922009944915771 seconds
# Final Answer: godly, Count: 5, Guesses: ['crane', 'lousy', 'folly', 'today', 'godly'], Time: 3.707101821899414 seconds
# Final Answer: threw, Count: 4, Guesses: ['crane', 'retro', 'tiger', 'threw'], Time: 0.5393280982971191 seconds
# Final Answer: fleet, Count: 4, Guesses: ['crane', 'depot', 'sweet', 'fleet'], Time: 0.46297311782836914 seconds
# Final Answer: grave, Count: 4, Guesses: ['crane', 'grate', 'prize', 'grave'], Time: 0.0017590522766113281 seconds
# Final Answer: inane, Count: 2, Guesses: ['crane', 'inane'], Time: 0.0005631446838378906 seconds
# Final Answer: shock, Count: 4, Guesses: ['crane', 'stick', 'mount', 'shock'], Time: 0.03834104537963867 seconds
# Final Answer: crave, Count: 2, Guesses: ['crane', 'crave'], Time: 0.0004990100860595703 seconds
# Final Answer: spite, Count: 4, Guesses: ['crane', 'slide', 'smite', 'spite'], Time: 0.2860691547393799 seconds
# Final Answer: valve, Count: 3, Guesses: ['crane', 'table', 'valve'], Time: 0.03421425819396973 seconds
# Final Answer: skimp, Count: 4, Guesses: ['crane', 'lousy', 'swift', 'skimp'], Time: 3.7071239948272705 seconds
# Final Answer: claim, Count: 3, Guesses: ['crane', 'clasp', 'claim'], Time: 0.0013210773468017578 seconds
# Final Answer: rainy, Count: 2, Guesses: ['crane', 'rainy'], Time: 0.0004646778106689453 seconds
# Final Answer: musty, Count: 5, Guesses: ['crane', 'lousy', 'husky', 'midge', 'musty'], Time: 3.7162978649139404 seconds
# Final Answer: pique, Count: 3, Guesses: ['crane', 'slide', 'pique'], Time: 0.28609299659729004 seconds
# Final Answer: daddy, Count: 4, Guesses: ['crane', 'aptly', 'daisy', 'daddy'], Time: 0.595524787902832 seconds
# Final Answer: quasi, Count: 5, Guesses: ['crane', 'flash', 'amass', 'toast', 'quasi'], Time: 0.04000210762023926 seconds
# Final Answer: arise, Count: 2, Guesses: ['crane', 'arise'], Time: 0.000492095947265625 seconds
# Final Answer: aging, Count: 3, Guesses: ['crane', 'taint', 'aging'], Time: 0.0036580562591552734 seconds
# Final Answer: valet, Count: 3, Guesses: ['crane', 'steal', 'valet'], Time: 0.030356884002685547 seconds
# Final Answer: opium, Count: 4, Guesses: ['crane', 'lousy', 'outgo', 'opium'], Time: 3.7139580249786377 seconds
# Final Answer: avert, Count: 3, Guesses: ['crane', 'later', 'avert'], Time: 0.04927492141723633 seconds
# Final Answer: stuck, Count: 3, Guesses: ['crane', 'stick', 'stuck'], Time: 0.03739213943481445 seconds
# Final Answer: recut, Count: 3, Guesses: ['crane', 'ulcer', 'recut'], Time: 0.0007719993591308594 seconds
# Final Answer: mulch, Count: 5, Guesses: ['crane', 'stick', 'could', 'gulch', 'mulch'], Time: 0.03798794746398926 seconds
# Final Answer: genre, Count: 2, Guesses: ['crane', 'genre'], Time: 0.0005450248718261719 seconds
# Final Answer: plume, Count: 4, Guesses: ['crane', 'slide', 'bloke', 'plume'], Time: 0.28899407386779785 seconds
# Final Answer: rifle, Count: 4, Guesses: ['crane', 'surge', 'fibre', 'rifle'], Time: 0.018552064895629883 seconds
# Final Answer: count, Count: 3, Guesses: ['crane', 'clink', 'count'], Time: 0.0005979537963867188 seconds
# Final Answer: incur, Count: 3, Guesses: ['crane', 'scorn', 'incur'], Time: 0.0004029273986816406 seconds
# Final Answer: total, Count: 3, Guesses: ['crane', 'aptly', 'total'], Time: 0.5922822952270508 seconds
# Final Answer: wrest, Count: 3, Guesses: ['crane', 'pried', 'wrest'], Time: 0.003744840621948242 seconds
# Final Answer: mocha, Count: 2, Guesses: ['crane', 'mocha'], Time: 0.0065517425537109375 seconds
# Final Answer: deter, Count: 3, Guesses: ['crane', 'retro', 'deter'], Time: 0.5332751274108887 seconds
# Final Answer: study, Count: 3, Guesses: ['crane', 'lousy', 'study'], Time: 3.7093002796173096 seconds
# Final Answer: lover, Count: 4, Guesses: ['crane', 'retro', 'loser', 'lover'], Time: 0.5352370738983154 seconds
# Final Answer: safer, Count: 6, Guesses: ['crane', 'later', 'wager', 'parer', 'baker', 'safer'], Time: 0.05082511901855469 seconds
# Final Answer: rivet, Count: 3, Guesses: ['crane', 'retro', 'rivet'], Time: 0.5335648059844971 seconds
# Final Answer: funny, Count: 3, Guesses: ['crane', 'stung', 'funny'], Time: 0.051522016525268555 seconds
# Final Answer: smoke, Count: 4, Guesses: ['crane', 'slide', 'stove', 'smoke'], Time: 0.28536486625671387 seconds
# Final Answer: mound, Count: 5, Guesses: ['crane', 'stung', 'found', 'whack', 'mound'], Time: 0.05207419395446777 seconds
# Final Answer: undue, Count: 3, Guesses: ['crane', 'singe', 'undue'], Time: 0.004563093185424805 seconds
# Final Answer: sedan, Count: 4, Guesses: ['crane', 'eaten', 'began', 'sedan'], Time: 0.004052162170410156 seconds
# Final Answer: pagan, Count: 4, Guesses: ['crane', 'manly', 'patio', 'pagan'], Time: 0.03681612014770508 seconds
# Final Answer: swine, Count: 3, Guesses: ['crane', 'shone', 'swine'], Time: 0.0014128684997558594 seconds
# Final Answer: guile, Count: 3, Guesses: ['crane', 'slide', 'guile'], Time: 0.28494715690612793 seconds
# Final Answer: gusty, Count: 5, Guesses: ['crane', 'lousy', 'husky', 'midge', 'gusty'], Time: 3.719003915786743 seconds
# Final Answer: equip, Count: 4, Guesses: ['crane', 'depot', 'spiel', 'equip'], Time: 0.4623270034790039 seconds
# Final Answer: tough, Count: 4, Guesses: ['crane', 'lousy', 'light', 'tough'], Time: 3.720144748687744 seconds
# Final Answer: canoe, Count: 2, Guesses: ['crane', 'canoe'], Time: 0.0004780292510986328 seconds
# Final Answer: chaos, Count: 3, Guesses: ['crane', 'clasp', 'chaos'], Time: 0.0012531280517578125 seconds
# Final Answer: covet, Count: 3, Guesses: ['crane', 'chest', 'covet'], Time: 0.0011031627655029297 seconds
# Final Answer: human, Count: 3, Guesses: ['crane', 'manly', 'human'], Time: 0.036618947982788086 seconds
# Final Answer: udder, Count: 5, Guesses: ['crane', 'retro', 'plier', 'queer', 'udder'], Time: 0.5419661998748779 seconds
# Final Answer: lunch, Count: 2, Guesses: ['crane', 'lunch'], Time: 0.0027778148651123047 seconds
# Final Answer: blast, Count: 4, Guesses: ['crane', 'flash', 'glass', 'blast'], Time: 0.03984403610229492 seconds
# Final Answer: stray, Count: 3, Guesses: ['crane', 'foray', 'stray'], Time: 0.06387090682983398 seconds
# Final Answer: manga, Count: 4, Guesses: ['crane', 'manly', 'siege', 'manga'], Time: 0.03664207458496094 seconds
# Final Answer: melee, Count: 4, Guesses: ['crane', 'slide', 'boule', 'melee'], Time: 0.28558897972106934 seconds
# Final Answer: lefty, Count: 4, Guesses: ['crane', 'depot', 'fetus', 'lefty'], Time: 0.4612729549407959 seconds
# Final Answer: quick, Count: 3, Guesses: ['crane', 'stick', 'quick'], Time: 0.03767681121826172 seconds
# Final Answer: paste, Count: 4, Guesses: ['crane', 'table', 'waste', 'paste'], Time: 0.03403210639953613 seconds
# Final Answer: given, Count: 4, Guesses: ['crane', 'olden', 'sheen', 'given'], Time: 0.057821035385131836 seconds
# Final Answer: octet, Count: 4, Guesses: ['crane', 'leech', 'dicey', 'octet'], Time: 0.0032448768615722656 seconds
# Final Answer: risen, Count: 4, Guesses: ['crane', 'inter', 'scrap', 'risen'], Time: 0.007627964019775391 seconds
# Final Answer: groan, Count: 2, Guesses: ['crane', 'groan'], Time: 0.0005190372467041016 seconds
# Final Answer: leaky, Count: 3, Guesses: ['crane', 'exalt', 'leaky'], Time: 0.0024809837341308594 seconds
# Final Answer: grind, Count: 2, Guesses: ['crane', 'grind'], Time: 0.0018858909606933594 seconds
# Final Answer: carve, Count: 2, Guesses: ['crane', 'carve'], Time: 0.00045990943908691406 seconds
# Final Answer: loose, Count: 4, Guesses: ['crane', 'slide', 'could', 'loose'], Time: 0.2854299545288086 seconds
# Final Answer: sadly, Count: 3, Guesses: ['crane', 'aptly', 'sadly'], Time: 0.5961117744445801 seconds
# Final Answer: spilt, Count: 3, Guesses: ['crane', 'lousy', 'spilt'], Time: 3.7039260864257812 seconds
# Final Answer: apple, Count: 4, Guesses: ['crane', 'table', 'crimp', 'apple'], Time: 0.03466010093688965 seconds
# Final Answer: slack, Count: 3, Guesses: ['crane', 'scald', 'slack'], Time: 0.0013570785522460938 seconds
# Final Answer: honey, Count: 4, Guesses: ['crane', 'olden', 'money', 'honey'], Time: 0.057847023010253906 seconds
# Final Answer: final, Count: 4, Guesses: ['crane', 'manly', 'zonal', 'final'], Time: 0.036345720291137695 seconds
# Final Answer: sheen, Count: 3, Guesses: ['crane', 'olden', 'sheen'], Time: 0.05778193473815918 seconds
# Final Answer: eerie, Count: 4, Guesses: ['crane', 'surge', 'three', 'eerie'], Time: 0.018218040466308594 seconds
# Final Answer: minty, Count: 4, Guesses: ['crane', 'synod', 'hunky', 'minty'], Time: 0.055786848068237305 seconds
# Final Answer: slick, Count: 3, Guesses: ['crane', 'stick', 'slick'], Time: 0.037637948989868164 seconds
# Final Answer: derby, Count: 5, Guesses: ['crane', 'retro', 'sever', 'perky', 'derby'], Time: 0.535369873046875 seconds
# Final Answer: wharf, Count: 3, Guesses: ['crane', 'shard', 'wharf'], Time: 0.004796743392944336 seconds
# Final Answer: spelt, Count: 3, Guesses: ['crane', 'depot', 'spelt'], Time: 0.46096277236938477 seconds
# Final Answer: coach, Count: 3, Guesses: ['crane', 'clasp', 'coach'], Time: 0.0013377666473388672 seconds
# Final Answer: erupt, Count: 3, Guesses: ['crane', 'pried', 'erupt'], Time: 0.0036840438842773438 seconds
# Final Answer: singe, Count: 2, Guesses: ['crane', 'singe'], Time: 0.004556179046630859 seconds
# Final Answer: price, Count: 3, Guesses: ['crane', 'point', 'price'], Time: 0.0007839202880859375 seconds
# Final Answer: spawn, Count: 3, Guesses: ['crane', 'snail', 'spawn'], Time: 0.000762939453125 seconds
# Final Answer: fairy, Count: 3, Guesses: ['crane', 'foray', 'fairy'], Time: 0.06475996971130371 seconds
# Final Answer: jiffy, Count: 5, Guesses: ['crane', 'lousy', 'ditty', 'hippy', 'jiffy'], Time: 3.711369037628174 seconds
# Final Answer: filmy, Count: 3, Guesses: ['crane', 'lousy', 'filmy'], Time: 3.703049898147583 seconds
# Final Answer: stack, Count: 4, Guesses: ['crane', 'scald', 'month', 'stack'], Time: 0.0018160343170166016 seconds
# Final Answer: chose, Count: 3, Guesses: ['crane', 'choke', 'chose'], Time: 0.00127410888671875 seconds
# Final Answer: sleep, Count: 4, Guesses: ['crane', 'depot', 'spiel', 'sleep'], Time: 0.4614908695220947 seconds
# Final Answer: ardor, Count: 2, Guesses: ['crane', 'ardor'], Time: 0.0010828971862792969 seconds
# Final Answer: nanny, Count: 4, Guesses: ['crane', 'taint', 'fanny', 'nanny'], Time: 0.003789186477661133 seconds
# Final Answer: niece, Count: 3, Guesses: ['crane', 'niche', 'niece'], Time: 0.0011992454528808594 seconds
# Final Answer: woozy, Count: 4, Guesses: ['crane', 'lousy', 'goody', 'woozy'], Time: 3.721958875656128 seconds
# Final Answer: handy, Count: 4, Guesses: ['crane', 'manly', 'dandy', 'handy'], Time: 0.03666210174560547 seconds
# Final Answer: grace, Count: 2, Guesses: ['crane', 'grace'], Time: 0.00040984153747558594 seconds
# Final Answer: ditto, Count: 4, Guesses: ['crane', 'lousy', 'pivot', 'ditto'], Time: 3.7149899005889893 seconds
# Final Answer: stank, Count: 2, Guesses: ['crane', 'stank'], Time: 0.002187013626098633 seconds
# Final Answer: cream, Count: 3, Guesses: ['crane', 'creak', 'cream'], Time: 0.0004830360412597656 seconds
# Final Answer: usual, Count: 4, Guesses: ['crane', 'aptly', 'shoal', 'usual'], Time: 0.595822811126709 seconds
# Final Answer: diode, Count: 3, Guesses: ['crane', 'slide', 'diode'], Time: 0.28580284118652344 seconds
# Final Answer: valor, Count: 3, Guesses: ['crane', 'foray', 'valor'], Time: 0.06461095809936523 seconds
# Final Answer: angle, Count: 2, Guesses: ['crane', 'angle'], Time: 0.0006189346313476562 seconds
# Final Answer: ninja, Count: 3, Guesses: ['crane', 'manly', 'ninja'], Time: 0.0364079475402832 seconds
# Final Answer: muddy, Count: 4, Guesses: ['crane', 'lousy', 'dumpy', 'muddy'], Time: 3.71041202545166 seconds
# Final Answer: chase, Count: 3, Guesses: ['crane', 'focus', 'chase'], Time: 0.0009300708770751953 seconds
# Final Answer: reply, Count: 3, Guesses: ['crane', 'retro', 'reply'], Time: 0.5373561382293701 seconds
# Final Answer: prone, Count: 2, Guesses: ['crane', 'prone'], Time: 0.0006439685821533203 seconds
# Final Answer: spoil, Count: 3, Guesses: ['crane', 'lousy', 'spoil'], Time: 3.705595016479492 seconds
# Final Answer: heart, Count: 3, Guesses: ['crane', 'ready', 'heart'], Time: 0.0008559226989746094 seconds
# Final Answer: shade, Count: 5, Guesses: ['crane', 'slate', 'shake', 'dumpy', 'shade'], Time: 0.025760889053344727 seconds
# Final Answer: diner, Count: 4, Guesses: ['crane', 'inter', 'moldy', 'diner'], Time: 0.00764012336730957 seconds
# Final Answer: arson, Count: 3, Guesses: ['crane', 'groan', 'arson'], Time: 0.0005199909210205078 seconds
# Final Answer: onion, Count: 4, Guesses: ['crane', 'synod', 'toxin', 'onion'], Time: 0.05573701858520508 seconds
# Final Answer: sleet, Count: 4, Guesses: ['crane', 'depot', 'sweet', 'sleet'], Time: 0.4620800018310547 seconds
# Final Answer: dowel, Count: 3, Guesses: ['crane', 'depot', 'dowel'], Time: 0.46088409423828125 seconds
# Final Answer: couch, Count: 3, Guesses: ['crane', 'could', 'couch'], Time: 0.0040090084075927734 seconds
# Final Answer: palsy, Count: 3, Guesses: ['crane', 'aptly', 'palsy'], Time: 0.5927371978759766 seconds
# Final Answer: bowel, Count: 3, Guesses: ['crane', 'depot', 'bowel'], Time: 0.46103811264038086 seconds
# Final Answer: smile, Count: 3, Guesses: ['crane', 'slide', 'smile'], Time: 0.2850840091705322 seconds
# Final Answer: evoke, Count: 4, Guesses: ['crane', 'slide', 'butte', 'evoke'], Time: 0.2856159210205078 seconds
# Final Answer: creek, Count: 3, Guesses: ['crane', 'creed', 'creek'], Time: 0.0011668205261230469 seconds
# Final Answer: lance, Count: 2, Guesses: ['crane', 'lance'], Time: 0.0003972053527832031 seconds
# Final Answer: eagle, Count: 4, Guesses: ['crane', 'table', 'pudgy', 'eagle'], Time: 0.03450608253479004 seconds
# Final Answer: idiot, Count: 4, Guesses: ['crane', 'lousy', 'pivot', 'idiot'], Time: 3.7085278034210205 seconds
# Final Answer: siren, Count: 4, Guesses: ['crane', 'inter', 'scrap', 'siren'], Time: 0.007913351058959961 seconds
# Final Answer: built, Count: 3, Guesses: ['crane', 'lousy', 'built'], Time: 3.7255091667175293 seconds
# Final Answer: embed, Count: 4, Guesses: ['crane', 'depot', 'edify', 'embed'], Time: 0.4741189479827881 seconds
# Final Answer: award, Count: 4, Guesses: ['crane', 'shard', 'would', 'award'], Time: 0.0052831172943115234 seconds
# Final Answer: dross, Count: 4, Guesses: ['crane', 'drift', 'drool', 'dross'], Time: 0.041541099548339844 seconds
# Final Answer: annul, Count: 4, Guesses: ['crane', 'manly', 'zonal', 'annul'], Time: 0.03782820701599121 seconds
# Final Answer: goody, Count: 3, Guesses: ['crane', 'lousy', 'goody'], Time: 3.7446391582489014 seconds
# Final Answer: frown, Count: 3, Guesses: ['crane', 'badge', 'frown'], Time: 0.0009248256683349609 seconds
# Final Answer: patio, Count: 3, Guesses: ['crane', 'aptly', 'patio'], Time: 0.596027135848999 seconds
# Final Answer: laden, Count: 4, Guesses: ['crane', 'eaten', 'drink', 'laden'], Time: 0.004433155059814453 seconds
# Final Answer: humid, Count: 3, Guesses: ['crane', 'lousy', 'humid'], Time: 3.7065672874450684 seconds
# Final Answer: elite, Count: 4, Guesses: ['crane', 'slide', 'olive', 'elite'], Time: 0.2889082431793213 seconds
# Final Answer: lymph, Count: 3, Guesses: ['crane', 'lousy', 'lymph'], Time: 3.7735507488250732 seconds
# Final Answer: edify, Count: 3, Guesses: ['crane', 'depot', 'edify'], Time: 0.4679419994354248 seconds
# Final Answer: might, Count: 4, Guesses: ['crane', 'lousy', 'whiff', 'might'], Time: 3.7360968589782715 seconds
# Final Answer: reset, Count: 4, Guesses: ['crane', 'retro', 'remit', 'reset'], Time: 0.5334558486938477 seconds
# Final Answer: visit, Count: 4, Guesses: ['crane', 'lousy', 'swift', 'visit'], Time: 3.7052969932556152 seconds
# Final Answer: gusto, Count: 4, Guesses: ['crane', 'lousy', 'spout', 'gusto'], Time: 3.702854871749878 seconds
# Final Answer: purse, Count: 3, Guesses: ['crane', 'surge', 'purse'], Time: 0.01848292350769043 seconds
# Final Answer: vapor, Count: 4, Guesses: ['crane', 'foray', 'valor', 'vapor'], Time: 0.06453084945678711 seconds
# Final Answer: crock, Count: 3, Guesses: ['crane', 'croup', 'crock'], Time: 0.001561880111694336 seconds
# Final Answer: write, Count: 3, Guesses: ['crane', 'trope', 'write'], Time: 0.0036270618438720703 seconds
# Final Answer: sunny, Count: 3, Guesses: ['crane', 'stung', 'sunny'], Time: 0.051403045654296875 seconds
# Final Answer: loath, Count: 3, Guesses: ['crane', 'flash', 'loath'], Time: 0.039572954177856445 seconds
# Average guesses per game: 3.408
# Average time per game: 0.588636923789978
